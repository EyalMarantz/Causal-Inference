# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
path = 'C:/Users/Eyal/Desktop/causal inference/project/tennis/'
original_data = pd.read_csv(path + 'data_diff_log.csv').drop(['Player'], axis=1)
treated = original_data[original_data['T'] == 1]
not_treated = original_data[original_data['T'] == 0]
data = pd.get_dummies(original_data, prefix=['Surface', 'Court', 'Best of'], columns=['Surface', 'Court', 'Best of'])
data.head()
# Out:
#    Rank   Age  weight_kg  height_cm  experience  T  Y  Surface_Carpet  \
# 0  81.0  30.0       88.0      196.0        12.0  1  0               0
# 1  80.0  30.0       88.0      196.0        12.0  1  1               0
# 2  71.0  30.0       88.0      196.0        12.0  0  1               0
# 3  71.0  30.0       88.0      196.0        12.0  0  1               0
# 4  71.0  30.0       88.0      196.0        12.0  1  0               0
#
#    Surface_Clay  Surface_Grass  Surface_Hard  Court_Indoor  Court_Outdoor  \
# 0             0              0             1             0              1
# 1             0              0             1             0              1
# 2             0              0             1             0              1
# 3             0              0             1             1              0
# 4             0              0             1             0              1
#
#    Best of_3  Best of_5
# 0          1          0
# 1          0          1
# 2          1          0
# 3          1          0
# 4          1          0

# %%
print(len(data))
# Out:
# 3135

# %%
from sklearn.linear_model import LogisticRegression
import seaborn as sns

corr = original_data.corr().round(3)
sns.heatmap(corr, cmap="Blues", annot=True)
plt.show()

corr = original_data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style type="text/css">
# #T_eb693_row0_col0, #T_eb693_row1_col1, #T_eb693_row2_col2, #T_eb693_row3_col3, #T_eb693_row4_col4, #T_eb693_row5_col5, #T_eb693_row6_col6, #T_eb693_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eb693_row0_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_eb693_row0_col2, #T_eb693_row0_col3, #T_eb693_row0_col5, #T_eb693_row0_col6, #T_eb693_row0_col7, #T_eb693_row1_col6, #T_eb693_row5_col0, #T_eb693_row5_col4, #T_eb693_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_eb693_row0_col4, #T_eb693_row1_col2, #T_eb693_row4_col6, #T_eb693_row5_col7, #T_eb693_row7_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_eb693_row1_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_eb693_row1_col3, #T_eb693_row5_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_eb693_row1_col4, #T_eb693_row3_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_eb693_row1_col5, #T_eb693_row7_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_eb693_row1_col7, #T_eb693_row6_col2, #T_eb693_row7_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col0, #T_eb693_row3_col2, #T_eb693_row6_col4, #T_eb693_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col3, #T_eb693_row3_col7, #T_eb693_row6_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col4, #T_eb693_row3_col5, #T_eb693_row3_col6, #T_eb693_row4_col2, #T_eb693_row4_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_eb693_row2_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_eb693_row3_col0, #T_eb693_row5_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_eb693_row3_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_eb693_row4_col0, #T_eb693_row6_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_eb693_row4_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_eb693_row4_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_eb693_row4_col7, #T_eb693_row6_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_eb693_row5_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_eb693_row5_col3, #T_eb693_row7_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_eb693_row6_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_eb693_row7_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_eb693_row7_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb693_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rank</th>
#       <th class="col_heading level0 col1" >Best of</th>
#       <th class="col_heading level0 col2" >Age</th>
#       <th class="col_heading level0 col3" >weight_kg</th>
#       <th class="col_heading level0 col4" >height_cm</th>
#       <th class="col_heading level0 col5" >experience</th>
#       <th class="col_heading level0 col6" >T</th>
#       <th class="col_heading level0 col7" >Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb693_level0_row0" class="row_heading level0 row0" >Rank</th>
#       <td id="T_eb693_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_eb693_row0_col1" class="data row0 col1" >0.007</td>
#       <td id="T_eb693_row0_col2" class="data row0 col2" >-0.029</td>
#       <td id="T_eb693_row0_col3" class="data row0 col3" >-0.044</td>
#       <td id="T_eb693_row0_col4" class="data row0 col4" >0.020</td>
#       <td id="T_eb693_row0_col5" class="data row0 col5" >-0.088</td>
#       <td id="T_eb693_row0_col6" class="data row0 col6" >-0.022</td>
#       <td id="T_eb693_row0_col7" class="data row0 col7" >-0.035</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row1" class="row_heading level0 row1" >Best of</th>
#       <td id="T_eb693_row1_col0" class="data row1 col0" >0.007</td>
#       <td id="T_eb693_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_eb693_row1_col2" class="data row1 col2" >0.021</td>
#       <td id="T_eb693_row1_col3" class="data row1 col3" >-0.006</td>
#       <td id="T_eb693_row1_col4" class="data row1 col4" >-0.012</td>
#       <td id="T_eb693_row1_col5" class="data row1 col5" >0.017</td>
#       <td id="T_eb693_row1_col6" class="data row1 col6" >-0.023</td>
#       <td id="T_eb693_row1_col7" class="data row1 col7" >-0.010</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_eb693_row2_col0" class="data row2 col0" >-0.029</td>
#       <td id="T_eb693_row2_col1" class="data row2 col1" >0.021</td>
#       <td id="T_eb693_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_eb693_row2_col3" class="data row2 col3" >0.030</td>
#       <td id="T_eb693_row2_col4" class="data row2 col4" >0.025</td>
#       <td id="T_eb693_row2_col5" class="data row2 col5" >0.931</td>
#       <td id="T_eb693_row2_col6" class="data row2 col6" >-0.002</td>
#       <td id="T_eb693_row2_col7" class="data row2 col7" >-0.001</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row3" class="row_heading level0 row3" >weight_kg</th>
#       <td id="T_eb693_row3_col0" class="data row3 col0" >-0.044</td>
#       <td id="T_eb693_row3_col1" class="data row3 col1" >-0.006</td>
#       <td id="T_eb693_row3_col2" class="data row3 col2" >0.030</td>
#       <td id="T_eb693_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_eb693_row3_col4" class="data row3 col4" >0.799</td>
#       <td id="T_eb693_row3_col5" class="data row3 col5" >-0.031</td>
#       <td id="T_eb693_row3_col6" class="data row3 col6" >0.031</td>
#       <td id="T_eb693_row3_col7" class="data row3 col7" >0.038</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row4" class="row_heading level0 row4" >height_cm</th>
#       <td id="T_eb693_row4_col0" class="data row4 col0" >0.020</td>
#       <td id="T_eb693_row4_col1" class="data row4 col1" >-0.012</td>
#       <td id="T_eb693_row4_col2" class="data row4 col2" >0.025</td>
#       <td id="T_eb693_row4_col3" class="data row4 col3" >0.799</td>
#       <td id="T_eb693_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_eb693_row4_col5" class="data row4 col5" >-0.031</td>
#       <td id="T_eb693_row4_col6" class="data row4 col6" >0.028</td>
#       <td id="T_eb693_row4_col7" class="data row4 col7" >0.029</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row5" class="row_heading level0 row5" >experience</th>
#       <td id="T_eb693_row5_col0" class="data row5 col0" >-0.088</td>
#       <td id="T_eb693_row5_col1" class="data row5 col1" >0.017</td>
#       <td id="T_eb693_row5_col2" class="data row5 col2" >0.931</td>
#       <td id="T_eb693_row5_col3" class="data row5 col3" >-0.031</td>
#       <td id="T_eb693_row5_col4" class="data row5 col4" >-0.031</td>
#       <td id="T_eb693_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_eb693_row5_col6" class="data row5 col6" >0.019</td>
#       <td id="T_eb693_row5_col7" class="data row5 col7" >0.016</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row6" class="row_heading level0 row6" >T</th>
#       <td id="T_eb693_row6_col0" class="data row6 col0" >-0.022</td>
#       <td id="T_eb693_row6_col1" class="data row6 col1" >-0.023</td>
#       <td id="T_eb693_row6_col2" class="data row6 col2" >-0.002</td>
#       <td id="T_eb693_row6_col3" class="data row6 col3" >0.031</td>
#       <td id="T_eb693_row6_col4" class="data row6 col4" >0.028</td>
#       <td id="T_eb693_row6_col5" class="data row6 col5" >0.019</td>
#       <td id="T_eb693_row6_col6" class="data row6 col6" >1.000</td>
#       <td id="T_eb693_row6_col7" class="data row6 col7" >0.188</td>
#     </tr>
#     <tr>
#       <th id="T_eb693_level0_row7" class="row_heading level0 row7" >Y</th>
#       <td id="T_eb693_row7_col0" class="data row7 col0" >-0.035</td>
#       <td id="T_eb693_row7_col1" class="data row7 col1" >-0.010</td>
#       <td id="T_eb693_row7_col2" class

# %%
import seaborn as sns

df1 = original_data[original_data['T'] == 1].groupby('Surface', as_index = False).sum()
df1.head()
df1['Proportion of Y=1 given T=1'] = df1['Y'] / df1['T']
sns.catplot(x="Surface", y='Proportion of Y=1 given T=1', kind="point", data=df1, linestyles=["--"])

# %%
def plot_e(data, clf):
    treated, not_treated = data[data['T'] == 1], data[data['T'] == 0]
    e1 = get_e(treated, clf)
    e0 = get_e(not_treated, clf)

    plt.hist(e0, bins=50)
    plt.hist(e1, bins=50)
    plt.legend(['Not Treatred', 'Treated'])
    plt.xlabel('Propensity Scores')
    plt.ylabel('Count')
    plt.show()

# %%
import matplotlib.pyplot as plt

clf =  RandomForestClassifier(max_depth=10)

X, t, y = get_X_t_y(data)
clf.fit(X, t)

plot_e(data, clf)

# %%
e = get_e(data, clf)
take = [i for i in range(len(e)) if 0.2 < e[i] < 0.8]
data = data.iloc[take]
plot_e(data, clf)

# %%
import seaborn as sns


sns.catplot(x="Surface", kind="count", palette="ch:.25", data=original_data)
plt.savefig(path + 'Surface.png')
plt.show()
sns.catplot(x="Court", kind="count", palette="ch:.25", data=original_data)
plt.savefig(path + 'Court.png')
plt.show()
sns.catplot(x="Best of", kind="count", palette="ch:.25", data=original_data)
plt.savefig(path + 'Best.png')

# %%
data[['Rank', 'Age','weight_kg', 'height_cm', 'experience', 'T', 'Y']].describe().T[['mean', 'std', 'min', 'max']].T.round(3)
# Out:
#          Rank     Age  weight_kg  height_cm  experience      T      Y
# mean   71.722  26.150     81.002    186.013       7.643  0.497  0.507
# std    53.812   3.798      7.425      7.047       3.590  0.500  0.500
# min     1.000  16.000     60.000    168.000       0.000  0.000  0.000
# max   851.000  48.000    108.000    211.000      27.000  1.000  1.000

# %%
def get_X_t_y(df):
    X, t, y = df.drop(['Y', 'T'], axis=True).to_numpy(), df['T'].to_numpy(), df['Y'].to_numpy()
    return X, t, y

# %%
from sklearn.neighbors import NearestNeighbors

def Matching(data):
    X0, t0, y0 = get_X_t_y(data[data['T'] == 0])
    X1, t1, y1 = get_X_t_y(data[data['T'] == 1])

    neigh0 = NearestNeighbors(n_neighbors=1)
    neigh0.fit(X0)
    nearest0 = neigh0.kneighbors(X1, return_distance=False)[:, 0]

    neigh1 = NearestNeighbors(n_neighbors=1)
    neigh1.fit(X1)
    nearest1 = neigh1.kneighbors(X0, return_distance=False)[:, 0]

    ITE = []
    
    for i in range(len(X1)):
        yi = y1[i]
        yj = y0[nearest0[i]]
        ITE.append(yi - yj)
        
    for i in range(len(X0)):
        yi = y0[i]
        yj = y1[nearest1[i]]
        ITE.append(yj - yi)
        
    ATT = sum(ITE) / len(ITE)
        
    return round(ATT, 4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

def S_learner(df):   
    X, t, y = get_X_t_y(df) 
    f = RandomForestClassifier(max_depth=100, random_state=0)
    f.fit(np.c_[X, t], y)  
    n = len(y)
    pred0 = f.predict(np.c_[X, np.zeros(n)])
    pred1 = f.predict(np.c_[X, np.ones(n)]) 
    ate = sum(pred1 - pred0) / n
    
    return round(ate,4)

# %%
from sklearn.linear_model import LogisticRegression

def T_learner(data):
    X, t, y = get_X_t_y(data)
    X_trated, t_treated, y_treated = get_X_t_y(data[data['T'] == 1])
    X_not, t_not, y_not = get_X_t_y(data[data['T'] == 0])

    f0 = RandomForestClassifier(max_depth=100, random_state=0) 
    f1 = RandomForestClassifier(max_depth=100, random_state=0)
    
    f1.fit(X_trated, y_treated)
    f0.fit(X_not, y_not)
    
    n = len(y)

    pred0 = f0.predict(X)
    pred1 = f1.predict(X)
    
    att = round(sum(pred1 - pred0) / n, 4)
    
    return att

# %%
def get_e(data, clf):
    X, t, y = get_X_t_y(data)
    e = clf.predict_proba(X)[:, 1]
    return e

def IPW(data):
    treated, not_treated = data[data['T'] == 1], data[data['T'] == 0]
    X, t, y = get_X_t_y(data)
    X1, _, y1 = get_X_t_y(treated)
    X0, _, y0 = get_X_t_y(not_treated)
    n = len(y)
    
#     clf =  RandomForestClassifier(max_depth=10, random_state=0)
#     clf.fit(X, t)

    e0 = get_e(not_treated, clf)
    e1 = get_e(treated, clf)
        
    ate = sum([y1[i] / e1[i] for i in range(len(y1))]) - sum([y0[i] / (1 - e0[i]) for i in range(len(y0))])
    ate /= n

    return round(ate, 4)

# %%
B = 1000
size = int(len(data) * 0.8)

ate_s, ate_t, ate_match, ate_ipw = [], [], [], []

for _ in range(B):
    sample = data.sample(size)
    ate_s.append(S_learner(sample))
    ate_t.append(T_learner(sample))
    ate_match.append(Matching(sample))
    ate_ipw.append(IPW(sample))

# %%
from scipy.stats import norm 

def ci(x):
    a = 0.05
    mean = sum(x) / len(x)
    var = (sum([xx**2 for xx in x]) / len(x)) - mean ** 2
    s = var ** 0.5
    l = round(mean - norm.ppf(1 - 0.5 * a) * s, 4)
    r = round(mean + norm.ppf(1 - 0.5 * a) * s, 4)
    
    return l, r

# %%
ate = [ate_s, ate_t, ate_match, ate_ipw]
methods = ['S learner', 'T learner', 'Matching', 'IPW']
l, r = [], []
m = []

for val in ate:
    l.append(ci(val)[0])
    r.append(ci(val)[1])
    m.append(round(sum(val) / len(val), 4))

res = {'Method' : methods, 'lower limit': l, 'Upper limit': r, 'Mean': m}
resdf = pd.DataFrame.from_dict(res)
resdf.head()
# Out:
#       Method  lower limit  Upper limit    Mean
# 0  S learner       0.2295       0.2779  0.2537
# 1  T learner       0.2386       0.2865  0.2625
# 2   Matching       0.1769       0.2101  0.1935
# 3        IPW       0.1748       0.2044  0.1896
